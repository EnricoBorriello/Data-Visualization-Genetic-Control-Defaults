# %%
import generate_figures as gf

# %% [markdown]
# ## Figure 1

# %%
help(gf.plot_figure_1)
gf.plot_figure_1()
# Out:
# Help on function plot_figure_1 in module generate_figures:
#
# plot_figure_1(csv_path='data/figure_1.csv', save_path='figure_1.pdf', show_plot=True)
#     Plot Figure 1 from a CSV file and optionally save it.
#
#     Parameters
#     ----------
#     csv_path : str
#         Path to the CSV file containing the data.
#     save_path : str
#         Path where the figure will be saved as PDF.
#     show_plot : bool
#         If True, displays the plot (for Jupyter Notebook). If False, only saves.

# %% [markdown]
# ## Figure 3A

# %%
help(gf.plot_figure_3a)
gf.plot_figure_3a()
# Out:
# Help on function plot_figure_3a in module generate_figures:
#
# plot_figure_3a(csv_path='data/figure_3A.txt', save_path='figure_3a.pdf', show_plot=True)
#     Plot Figure 3A: Average fitness over time.
#
#     Parameters
#     ----------
#     csv_path : str
#         Path to the TXT file containing the data.
#     save_path : str
#         Path where the figure will be saved as PDF.
#     show_plot : bool
#         If True, displays the plot (for Jupyter Notebook). If False, only saves.

# %% [markdown]
# # Figure 3B

# %%
help(gf.plot_figure_3b)
gf.plot_figure_3b()
# Out:
# Help on function plot_figure_3b in module generate_figures:
#
# plot_figure_3b(csv_path='data/figure_3B.txt', save_path='figure_3b.pdf', show_plot=True)
#     Plot Figure 3B: Average fitness over time (short timescale).
#
#     Parameters
#     ----------
#     csv_path : str
#         Path to the TXT file containing the data.
#     save_path : str
#         Path where the figure will be saved as PDF.
#     show_plot : bool
#         If True, displays the plot. If False, only saves.

# %% [markdown]
# # Figure 3C

# %%
help(gf.plot_figure_3c)
gf.plot_figure_3c()
# Out:
# Help on function plot_figure_3c in module generate_figures:
#
# plot_figure_3c(csv_path='data/figure_3C.csv', save_path='figure_3c.pdf', show_plot=True)
#     Plot Figure 3C: Average fitness over time in three environments.
#
#     Parameters
#     ----------
#     csv_path : str
#         Path to the CSV file containing the data.
#     save_path : str
#         Path where the figure will be saved as PDF.
#     show_plot : bool
#         If True, displays the plot. If False, only saves.

# %% [markdown]
# # Figure 3D

# %%
help(gf.plot_figure_3d)
gf.plot_figure_3d()
# Out:
# Help on function plot_figure_3d in module generate_figures:
#
# plot_figure_3d(csv_path='data/figure_3D.csv', save_path='figure_3d.pdf', show_plot=True)
#     Plot Figure 3D: 3D plot of individual fitness over time for five organisms.
#
#     Parameters
#     ----------
#     csv_path : str
#         Path to the CSV file containing the data.
#     save_path : str
#         Path where the figure will be saved as PDF.
#     show_plot : bool
#         If True, displays the plot. If False, only saves.

# %% [markdown]
# # Figure 3E

# %%
help(gf.plot_figure_3e)
gf.plot_figure_3e()
# Out:
# Help on function plot_figure_3e in module generate_figures:
#
# plot_figure_3e(txt_path='data/figure_3E.txt', save_path='figure_3e.pdf', show_plot=True)
#     Plot Figure 3E: Average fitness over time.
#
#     Parameters
#     ----------
#     txt_path : str
#         Path to the TXT file containing the data.
#     save_path : str
#         Path where the figure will be saved as PDF.
#     show_plot : bool
#         If True, displays the plot. If False, only saves.

# %% [markdown]
# # Figure 4

# %%
help(gf.plot_figure_4)
gf.plot_figure_4()
# Out:
# Help on function plot_figure_4 in module generate_figures:
#
# plot_figure_4(csv_path='data/figure_4.csv', save_path='figure_4.pdf', show_plot=True)
#     Plot Figure 4: Scatter plot of genome vs. environmental complexity colored by perfection index.
#
#     Parameters
#     ----------
#     csv_path : str
#         Path to the CSV file containing the data.
#     save_path : str
#         Path where the figure will be saved as PDF.
#     show_plot : bool
#         If True, displays the plot. If False, only saves.

# %% [markdown]
# # Figure 5

# %%
help(gf.plot_figure_5)
gf.plot_figure_5()
# Out:
# Help on function plot_figure_5 in module generate_figures:
#
# plot_figure_5(save_path='figure_5.pdf', show_plot=True)
#     Plot Figure 5: Fitness trajectories with error bars for two model sets.
#
#     Parameters
#     ----------
#     save_path : str
#         Path where the figure will be saved as PDF.
#     show_plot : bool
#         If True, displays the plot. If False, only saves.

# %% [markdown]
# # Figure 6

# %%
help(gf.plot_figure_6)
gf.plot_figure_6()
# Out:
# Help on function plot_figure_6 in module generate_figures:
#
# plot_figure_6(csv_path='data/figure_6.csv', save_path='figure_6.pdf', show_plot=True)
#     Plot Figure 6: Relationship between starting gene length and average coding sequence length.
#
#     Parameters
#     ----------
#     csv_path : str
#         Path to the CSV file containing the data.
#     save_path : str
#         Path where the figure will be saved as PDF.
#     show_plot : bool
#         If True, displays the plot. If False, only saves.

# %% [markdown]
# # Figure 7

# %%
help(gf.plot_figure_7)
gf.plot_figure_7()
# Out:
# Help on function plot_figure_7 in module generate_figures:
#
# plot_figure_7(csv_path='data/figure_7.csv', save_path='figure_7.pdf', show_plot=True)
#     Plot Figure 7: Relationship between regulatory ratio and gene expression.
#
#     Parameters
#     ----------
#     csv_path : str
#         Path to the CSV file containing the data.
#     save_path : str
#         Path where the figure will be saved as PDF.
#     show_plot : bool
#         If True, displays the plot. If False, only saves.

# %% [markdown]
# # Figure 8

# %%
help(gf.plot_figure_8)
gf.plot_figure_8()
# Out:
# Help on function plot_figure_8 in module generate_figures:
#
# plot_figure_8(csv_path='data/figure_8_all.csv', save_path='figure_8_all.pdf', show_plot=True)
#     Plot Figure 8: Perfection index vs. element length ratio, colored by time to plateau.
#
#     Parameters
#     ----------
#     csv_path : str
#         Path to the CSV file containing the data.
#     save_path : str
#         Path where the figure will be saved as PDF.
#     show_plot : bool
#         If True, displays the plot. If False, only saves.

# %% [markdown]
# ## Figure 8 replicates

# %%
help(gf.plot_figure_8_replicates)
gf.plot_figure_8_replicates()
# Out:
# Help on function plot_figure_8_replicates in module generate_figures:
#
# plot_figure_8_replicates(csv_path='data/figure_8_rep.csv', save_path='figure_8_rep.pdf', show_plot=True)
#     Plot Figure 8 (replicates): Perfection index vs. element length ratio,
#     colored by time to plateau, with annotated regions for replicate sets.
#
#     Parameters
#     ----------
#     csv_path : str
#         Path to the CSV file containing the replicate data.
#     save_path : str
#         Path where the figure will be saved as PDF.
#     show_plot : bool
#         If True, displays the plot. If False, only saves.
